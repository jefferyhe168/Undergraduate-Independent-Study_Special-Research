# %%
# !pip install ckip-segmenter
# Out:
# Collecting ckip-segmenter
#   Downloading ckip_segmenter-1.0.2-py3-none-any.whl (7.8 kB)
# Installing collected packages: ckip-segmenter
# Successfully installed ckip-segmenter-1.0.2

# %%
from ckip import CkipSegmenter

# %%
segmenter = CkipSegmenter()
text =( "這會是一件很耗時的工作，他決定先把後腿拖回去，然後再回來處理。這得花上一整晚，而且一定會很冷。"
        "他花了將近二十分鐘才將腿拖回棚屋，回去時已經筋疲力盡了。他將肉沿著牆儲存好，然後回到母麋鹿那裡。"
        "已經到了正午，他非常饑餓。於是花了十五分鐘收集木材，在麋鹿旁邊生火。當火燒得很旺盛時，他從抬走的後腿旁邊的臀部切下一條肉，懸在一根木棍上，整塊肉幾乎就在火燄裡。"
        "烤肉的同時，他回頭去切割和剝皮。他切下右前肩，就跟切後腿一樣，將肩胛骨切開，接著切開腿，然後拖回營地。回來時，木棍上的肉已烤得非常完美：外頭有點焦，裡頭則熟透了。" )
result = segmenter.seg(text)

# %%
# result.res is a list of tuples contain a token and its pos-tag.
# print('result.res: {}\n'.format(result.res))

# result.tok and result.pos contains only tokens and pos-tags respectively.
print('result.tok: {}\n'.format(result.tok))
print('result.pos: {}\n'.format(result.pos))
# Out:
# result.tok: ['這會', '是', '一', '件', '很', '耗時', '的', '工作', '，', '他', '決定', '先', '把', '後腿', '拖回', '去', '，', '然後', '再', '回來', '處理', '。', '這', '得', '花上', '一', '整', '晚', '，', '而且', '一定', '會', '很', '冷', '。', '他', '花', '了', '將近', '二十', '分鐘', '才', '將', '腿', '拖回', '棚屋', '，', '回去', '時', '已經', '筋疲力盡', '了', '。', '他', '將', '肉', '沿', '著', '牆', '儲存', '好', '，', '然後', '回到', '母', '麋鹿', '那裡', '。', '已經', '到', '了', '正午', '，', '他', '非常', '饑餓', '。', '於是', '花', '了', '十五', '分鐘', '收集', '木材', '，', '在', '麋鹿', '旁邊', '生火', '。', '當', '火燒', '得', '很', '旺盛', '時', '，', '他', '從', '抬走', '的', '後腿', '旁邊', '的', '臀部', '切下', '一', '條', '肉', '，', '懸', '在', '一', '根', '木棍', '上', '，', '整', '塊', '肉', '幾乎', '就', '在', '火燄', '裡', '。', '烤肉', '的', '同時', '，', '他', '回頭', '去', '切割', '和', '剝皮', '。', '他', '切下', '右前肩', '，', '就', '跟', '切', '後腿', '一樣', '，', '將', '肩胛骨', '切開', '，', '接著', '切開', '腿', '，', '然後', '拖回', '營地', '。', '回來', '時', '，', '木棍', '上', '的', '肉', '已', '烤', '得', '非常', '完美', '：', '外頭', '有點', '焦', '，', '裡頭', '則', '熟透', '了', '。']
#
# result.pos: ['Nd', 'SHI', 'Neu', 'Nf', 'Dfa', 'VH', 'DE', 'Na', 'COMMACATEGORY', 'Nh', 'VE', 'D', 'P', 'Na', 'VC', 'T', 'COMMACATEGORY', 'D', 'D', 'VA', 'VC', 'PERIODCATEGORY', 'Nep', 'D', 'VC', 'Neu', 'Neqa', 'VH', 'COMMACATEGORY', 'Cbb', 'D', 'D', 'Dfa', 'VH', 'PERIODCATEGORY', 'Nh', 'VC', 'Di', 'Da', 'Neu', 'Nf', 'Da', 'P', 'Na', 'VC', 'Na', 'COMMACATEGORY', 'VA', 'Ng', 'D', 'VH', 'T', 'PERIODCATEGORY', 'Nh', 'P', 'Na', 'P', 'Di', 'Na', 'VC', 'VH', 'COMMACATEGORY', 'D', 'VCL', 'A', 'Na', 'Ncd', 'PERIODCATEGORY', 'D', 'VCL', 'Di', 'Nd', 'COMMACATEGORY', 'Nh', 'Dfa', 'VH', 'PERIODCATEGORY', 'Cbb', 'VC', 'Di', 'Neu', 'Nf', 'VC', 'Na', 'COMMACATEGORY', 'P', 'Na', 'Ncd', 'VA', 'PERIODCATEGORY', 'P', 'VC', 'DE', 'Dfa', 'VH', 'Ng', 'COMMACATEGORY', 'Nh', 'P', 'VC', 'DE', 'Na', 'Ncd', 'DE', 'Nc', 'VC', 'Neu', 'Nf', 'Na', 'COMMACATEGORY', 'VC', 'P', 'Neu', 'Nf', 'Na', 'Ncd', 'COMMACATEGORY', 'Neqa', 'Nf', 'Na', 'Da', 'D', 'P', 'Na', 'Ncd', 'PERIODCATEGORY', 'Na', 'DE', 'Nd', 'COMMACATEGORY', 'Nh', 'D', 'D', 'VC', 'Caa', 'VB', 'PERIODCATEGORY', 'Nh', 'VC', 'Na', 'COMMACATEGORY', 'D', 'P', 'VC', 'Na', 'VH', 'COMMACATEGORY', 'P', 'Na', 'VC', 'COMMACATEGORY', 'D', 'VC', 'Na', 'COMMACATEGORY', 'D', 'VC', 'Nc', 'PERIODCATEGORY', 'VA', 'Ng', 'COMMACATEGORY', 'Na', 'Ncd', 'DE', 'Na', 'D', 'VC', 'DE', 'Dfa', 'VH', 'COLONCATEGORY', 'Ncd', 'Dfa', 'VH', 'COMMACATEGORY', 'Ncd', 'D', 'VH', 'T', 'PERIODCATEGORY']
